# %% [markdown]
# # **Graded Challenge 1**
# Name : `Kamil Riyadi Alam Situmeang`\
# Batch : `FTDS009`\
# This project is intended as fulfillment for an assignment of Hacktiv8 Fulltime Data Scientiest Bootcamp program.

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# ### I.1 Project Background
# My Name is Kamil Riyadi Alam Situmeang, I am a junior data analyst currently working for Team Rocket under the research team.
#
# Team Rocket itself is an Organization based in Kanto and Johto regions. Team Rocket main focus is capturing rare and strong Pokemon.
#
# `"Giovanni"`, Team Rocket Boss is currently `aim to capture "Mewtwo"`, most strongest Pokemon in Kanto region.
#
# He asks the research team to investigate more about "Mewtwo", and ask us to prepare a Pokemon team consist of 6 Pokemon to battle and capture "Mewtwo".

# %% [markdown]
# ### I.2 Dataset Source and Description
# `Dataset` for this project is publicly made available and maintained `by Alberto Barradas` through his [Kaggle page](https://www.kaggle.com/abcsds/pokemon).
#
# This dataset has `CC0:Public Domain License`, means everyone has the rights to copy, modify, distribute and perform the work, even for commercial purposes, all without asking permission.

# %% [markdown]
# This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed.
#
# The feature of this data is:
#
# - #: ID for each pokemon
# - Name: Name of each pokemon
# - Type 1: Each pokemon has a type, this determines weakness/resistance to attacks
# - Type 2: Some pokemon are dual type and have 2
# - Total: sum of all stats that come after this, a general guide to how strong a pokemon is
# - HP: hit points, or health, defines how much damage a pokemon can withstand before fainting
# - Attack: the base modifier for normal attacks (eg. Scratch, Punch)
# - Defense: the base damage resistance against normal attacks
# - SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# - SP Def: the base damage resistance against special attacks
# - Speed: determines which pokemon attacks first each round
# - Generation : determines which generation (in pokemon video game) is the pokemon from
# - Legendary : determines wether a pokemon is legendary pokemon or not

# %% [markdown]
# ### I.3 Objective
# Based on the Project Background, the objectives are:
# - Investigate about `Mewtwo`
# - Make a recommendation of Pokemon team consist of 6 of Pokemon to battle and capture Mewtwo

# %% [markdown]
# ## II. Importing Library
#
# Raw dataset for this project is saved in .csv format. In order to work with the dataset more easily, I choose to use pandas and numpy.\
# pandas will be used for working with tabular data while numpy will be used for working with array of data.

# %%
# Importing libraries into jupyter notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# Checking libraries version
print(pd.__version__)
print(np.__version__)

# Set to shows all columns in dataframe
pd.set_option('display.max.columns', None)
# Out:
# 1.4.1
# 1.22.2

# %% [markdown]
# ## III. Data Loading

# %% [markdown]
# First, after downloading the dataset and put it in the same folder as this notebook is. I am importing the `.csv` file into jupyter notebook.

# %%
# Importing Pokemon.csv into jupyter notebook and save it inside df variable
raw_df = pd.read_csv('Pokemon.csv')

# %% [markdown]
# Before continue to the next step, I would like see overview of the dataset

# %%
# Quick info about the dataset
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# As from the result above, We can see that `this dataset consits of 800 entries and 13 columns`.
#
# Most `data type` in the entries is `integer`, some of them are is `object`, and there is one column that has `boolean` type.
#
# `Most columns has 800 Non-Null Count`, same number with total entries in the dataset. `This means all entries in columns has values.`
#
# `'Type 2' column` has less Non-Null Count than 800, means this column `has empty value` in some of its entries.

# %% [markdown]
# I would like to know the spread of the data inside the dataset, So I use .describe() method in pandas to get statistical descriptive of my dataset.

# %%
#Statistical Descriptive of the dataset
raw_df.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# ## IV. Data Cleaning
# In this phase, any missing values, error, or outlier inside the dataset will be taken care of. This phase aims to get clean data for analysis.

# %% [markdown]
# Prior to start any data cleaning process, I decided to take a look a subset from the dataset to give a preview on how's the table is look like

# %%
# first 10 entries for overview purpose
raw_df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# ### IV.1 Standard Missing Values
# `Standard missing values` means cell in column(s) with no entry, usually is `identified by NaN or NA` in the cell.
#
# This process aims to `identify standard missing values` in the dataset.

# %%
# This process will count and `summarize all missing values` inside each column(s)
raw_df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# from result above, I can pretty much say that each column has no Nan value except `"Type 2"` column.
#
# This result is inline with the result on data loading section.

# %% [markdown]
# ### IV.2 Non-Standard Missing Values
# Sometimes missing values also takes in other form such as ['na', 'N/A', '-', '', etc.], is usually identified as `Non-standard missing values`.
#
# This process aims to `identify Non-Standard Missing Values` in the dataset.

# %% [markdown]
# In order to identify any Non-standard missing values, I will utilize pandas `.value_count()` method. This method will list all unique entries and its frequency in each column.
#
# In this process also I will identify any possible `Unexpected Missing Values`, means :
# - any entry that has different data type as other entry in the same column,
# - any entry that did not match the column description,
# - any entry that is should be unique (such as "ID number" or "Name") but has frequency > 1
#
# will considered as missing value.

# %%
# #: ID for each pokemon
x = raw_df['#'].value_counts()
pd.set_option('display.max_rows', None)

print(x)
print(x.dtype)
# Out:
# 479    6
# 386    4
# 710    4
# 711    4
# 646    3
# 150    3
# 413    3
# 6      3
# 319    2
# 642    2
# 302    2
# 303    2
# 94     2
# 334    2
# 306    2
# 308    2
# 641    2
# 65     2
# 80     2
# 428    2
# 310    2
# 460    2
# 645    2
# 323    2
# 647    2
# 648    2
# 445    2
# 381    2
# 115    2
# 248    2
# 531    2
# 208    2
# 212    2
# 214    2
# 380    2
# 555    2
# 181    2
# 229    2
# 492    2
# 282    2
# 254    2
# 487    2
# 257    2
# 260    2
# 142    2
# 475    2
# 678    2
# 127    2
# 130    2
# 448    2
# 384    2
# 376    2
# 357    1
# 358    1
# 360    1
# 2      1
# 363    1
# 364    1
# 365    1
# 367    1
# 332    1
# 368    1
# 369    1
# 370    1
# 371    1
# 372    1
# 374    1
# 375    1
# 377    1
# 355    1
# 353    1
# 352    1
# 351    1
# 333    1
# 335    1
# 336    1
# 337    1
# 338    1
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# 345    1
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# 281    1
# 280    1
# 279    1
# 221    1
# 211    1
# 213    1
# 215    1
# 216    1
# 217    1
# 218    1
# 219    1
# 220    1
# 222    1
# 278    1
# 223    1
# 224    1
# 225    1
# 226    1
# 227    1
# 228    1
# 230    1
# 231    1
# 210    1
# 209    1
# 207    1
# 206    1
# 189    1
# 190    1
# 191    1
# 192    1
# 193    1
# 194    1
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# 200    1
# 201    1
# 202    1
# 203    1
# 204    1
# 205    1
# 232    1
# 233    1
# 234    1
# 258    1
# 261    1
# 262    1
# 263    1
# 264    1
# 265    1
# 266    1
# 267    1
# 268    1
# 269    1
# 270    1
# 271    1
# 272    1
# 273    1
# 274    1
# 275    1
# 276    1
# 277    1
# 259    1
# 256    1
# 235    1
# 255    1
# 236    1
# 237    1
# 238    1
# 239    1
# 240    1
# 241    1
# 242    1
# 243    1
# 244    1
# 245    1
# 246    1
# 247    1
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# 721    1
# Name: #, dtype: int64
# int64

# %% [markdown]
# From result above for "#" column has no Non-standard missing value but might has unexpected missing values.
#
# We can see there is several "Pokemon #" that has frequency more than 1. This may indicates there is duplicate entries in the dataset.
#
#
# In order to extract those duplicate entries in the dataset, I will query the dataset.

# %% [markdown]
# Before querying, in order to make better readibility for the dataset, I decided to change `#` column name into `Pokedex_num`

# %%
# Renaming `#` column into `Pokedex_num`
raw_df.rename(columns={"#":"Pokedex_num"}, inplace=True)

# %% [markdown]
# First, I will create dictionary about `pokedex_num` and its frequency.
#
# The result will look alike `.value_counts()` but in dictionary format.

# %%
# Extracting Pokedex_num and put it in inside dictionary
poke_num = raw_df['Pokedex_num'].tolist() # turn all entries in 'Pokedex_num' column into list
freq = {} # create empty dictionary for contain all 'Pokedex_num' and its frequency

# Loop the `poke_num` list, and count the frequency of appearence within the list
# Dictionary will have `Pokedex_num` as its key, and frequency as its value
for i in poke_num:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1

print(freq)
# Out:
# {1: 1, 2: 1, 3: 2, 4: 1, 5: 1, 6: 3, 7: 1, 8: 1, 9: 2, 10: 1, 11: 1, 12: 1, 13: 1, 14: 1, 15: 2, 16: 1, 17: 1, 18: 2, 19: 1, 20: 1, 21: 1, 22: 1, 23: 1, 24: 1, 25: 1, 26: 1, 27: 1, 28: 1, 29: 1, 30: 1, 31: 1, 32: 1, 33: 1, 34: 1, 35: 1, 36: 1, 37: 1, 38: 1, 39: 1, 40: 1, 41: 1, 42: 1, 43: 1, 44: 1, 45: 1, 46: 1, 47: 1, 48: 1, 49: 1, 50: 1, 51: 1, 52: 1, 53: 1, 54: 1, 55: 1, 56: 1, 57: 1, 58: 1, 59: 1, 60: 1, 61: 1, 62: 1, 63: 1, 64: 1, 65: 2, 66: 1, 67: 1, 68: 1, 69: 1, 70: 1, 71: 1, 72: 1, 73: 1, 74: 1, 75: 1, 76: 1, 77: 1, 78: 1, 79: 1, 80: 2, 81: 1, 82: 1, 83: 1, 84: 1, 85: 1, 86: 1, 87: 1, 88: 1, 89: 1, 90: 1, 91: 1, 92: 1, 93: 1, 94: 2, 95: 1, 96: 1, 97: 1, 98: 1, 99: 1,
2, 382: 2, 383: 2, 384: 2, 385: 1, 386: 4, 387: 1, 388: 1, 389: 1, 390: 1, 391: 1, 392: 1, 393: 1, 394: 1, 395: 1, 396: 1, 397: 1, 398: 1, 399: 1, 400: 1, 401: 1, 402: 1, 403: 1, 404: 1, 405: 1, 406: 1, 407: 1, 408: 1, 409: 1, 410: 1, 411: 1, 412: 1, 413: 3, 414: 1, 415: 1, 416: 1, 417: 1, 418: 1, 419: 1, 420: 1, 421: 1, 422: 1, 423: 1, 424: 1, 425: 1, 426: 1, 427: 1, 428: 2, 429: 1, 430: 1, 431: 1, 432: 1, 433: 1, 434: 1, 435: 1, 436: 1, 437: 1, 438: 1, 439: 1, 440: 1, 441: 1, 442: 1, 443: 1, 444: 1, 445: 2, 446: 1, 447: 1, 448: 2, 449: 1, 450: 1, 451: 1, 452: 1, 453: 1, 454: 1, 455: 1, 456: 1, 457: 1, 458: 1, 459: 1, 460: 2, 461: 1, 462: 1, 463: 1, 464: 1, 465: 1, 466: 1, 467: 1, 468: 1, 469: 1, 470: 1, 471: 1, 472: 1, 473: 1, 474: 1, 475: 2, 476: 1, 477: 1, 478: 1, 479: 6, 480: 1, 481: 1, 482: 1, 483: 1, 484: 1, 485: 1, 486: 1, 487: 2, 488: 1, 489: 1, 490: 1, 491: 1, 492: 2, 493: 1, 494: 1, 495: 1, 496: 1, 497: 1, 498: 1, 499: 1, 500: 1, 501: 1, 502: 1, 503: 1, 504: 1, 505: 1, 506: 1, 507: 1, 508: 1, 509: 1, 510: 1, 511: 1, 512: 1, 513: 1, 514 ...

# %% [markdown]
# Second, I will extract all `Pokedex_num` that has frequency greater than 2.
#
# The result will be then put inside a list.

# %%
# Extracting `Pokedex_num` that has frequency > 1

pairs = freq.items() # list all pairs of (key, value) inside `freq` dictionary
filtered = {key for key, value in pairs if value > 1} # filter the value that is greater than 1
filtered = list(filtered) # turn the dictionary into a list

print(filtered)
print(type(filtered))
# Out:
# [384, 257, 130, 3, 260, 382, 6, 383, 386, 9, 641, 642, 645, 646, 142, 15, 647, 648, 18, 531, 150, 282, 413, 678, 681, 555, 428, 302, 303, 306, 308, 181, 310, 445, 319, 448, 65, 323, 710, 711, 460, 334, 719, 80, 208, 720, 212, 214, 475, 94, 479, 354, 376, 229, 359, 487, 362, 492, 115, 373, 248, 380, 381, 254, 127]
# <class 'list'>

# %% [markdown]
# Third, I will use those `filtered` list, for filtering the dataframe and take a closer look to the duplicate data.

# %%
# Querying the DataFrame
# Use `filtered` to filter all Pokemon that might be a duplicate entries

raw_df[
    (raw_df['Pokedex_num'].isin(filtered))
]
# Out:
#      Pokedex_num                       Name    Type 1    Type 2  Total   HP  \
# 2              3                   Venusaur     Grass    Poison    525   80
# 3              3      VenusaurMega Venusaur     Grass    Poison    625   80
# 6              6                  Charizard      Fire    Flying    534   78
# 7              6  CharizardMega Charizard X      Fire    Dragon    634   78
# 8              6  CharizardMega Charizard Y      Fire    Flying    634   78
# 11             9                  Blastoise     Water       NaN    530   79
# 12             9    BlastoiseMega Blastoise     Water       NaN    630   79
# 18            15                   Beedrill       Bug    Poison    395   65
# 19            15      BeedrillMega Beedrill       Bug    Poison    495   65
# 22            18                    Pidgeot    Normal    Flying    479   83
# 23            18        PidgeotMega Pidgeot    Normal    Flying    579   83
# 70            65                   Alakazam   Psychic       NaN    500   55
# 71            65      AlakazamMega Alakazam   Psychic       NaN    590   55
# 86            80                    Slowbro     Water   Psychic    490   95
# 87            80        SlowbroMega Slowbro     Water   Psychic    590   95
# 101           94                     Gengar     Ghost    Poison    500   60
# 102           94          GengarMega Gengar     Ghost    Poison    600   60
# 123          115                 Kangaskhan    Normal       NaN    490  105
# 124          115  KangaskhanMega Kangaskhan    Normal       NaN    590  105
# 136          127                     Pinsir       Bug       NaN    500   65
# 137          127          PinsirMega Pinsir       Bug    Flying    600   65
# 140          130                   Gyarados     Water    Flying    540   95
# 141          130      GyaradosMega Gyarados     Water      Dark    640   95
# 153          142                 Aerodactyl      Rock    Flying    515   80
# 154          142  AerodactylMega Aerodactyl      Rock    Flying    615   80
# 162          150                     Mewtwo   Psychic       NaN    680  106
# 163          150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106
# 164          150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106
# 195          181                   Ampharos  Electric       NaN    510   90
# 196          181      AmpharosMega Ampharos  Electric    Dragon    610   90
# 223          208                    Steelix     Steel    Ground    510   75
# 224          208        SteelixMega Steelix     Steel    Ground    610   75
# 228          212                     Scizor       Bug     Steel    500   70
# 229          212          ScizorMega Scizor       Bug     Steel    600   70
# 231          214                  Heracross       Bug  Fighting    500   80
# 232          214    HeracrossMega Heracross       Bug  Fighting    600   80
# 247          229                   Houndoom      Dark      Fire    500   75
# 248          229      HoundoomMega Houndoom      Dark      Fire    600   75
# 267          248                  Tyranitar      Rock      Dark    600  100
# 268          248    TyranitarMega Tyranitar      Rock      Dark    700  100
# 274          254                   Sceptile     Grass       NaN    530   70
# 275          254      SceptileMega Sceptile     Grass    Dragon    630   70
# 278          257                   Blaziken      Fire  Fighting    530   80
# 279          257      BlazikenMega Blaziken      Fire  Fighting    630   80
# 282          260                   Swampert     Water    Ground    535  100
# 283          260      SwampertMega Swampert     Water    Ground    635  100
# 305          282                  Gardevoir   Psychic     Fairy    518   68
# 306          282    GardevoirMega Gardevoir   Psychic     Fairy    618   68
# 326          302                    Sableye      Dark     Ghost    380   50
# 327          302        SableyeMega Sableye      Dark     Ghost    480   50
# 328          303                     Mawile     Steel     Fairy    380   50
# 329          303          MawileMega Mawile     Steel     Fairy    480   50
# 332          306                     Aggron     Steel      Rock    530   70
# 333          306          AggronMega Aggron     Steel       NaN    630   70
# 335          308                   Medicham  Fighting   Psychic    410   60
# 336          308      MedichamMega Medicham  Fighting   Psychic    510   60
# 338          310                  Manectric  Electric       NaN    475   70
# 339          310    ManectricMega Manectric  Electric       NaN    575   70
# 348          319                   Sharpedo     Water      Dark    460   70
# 349          319      SharpedoMega Sharpedo     Water      Dark    560   70
# 353          323                   Camerupt      Fire    Ground    460   70
# 354          323      CameruptMega Camerupt      Fire    Ground    560   70
# 365          334                    Altaria    Dragon    Flying    490   75
# 366          334        AltariaMega Altaria    Dragon     Fairy    590   75
# 386          354                    Banette     Ghost       NaN    455   64
# 387          354        BanetteMega Banette     Ghost       NaN    555   64
# 392          359                      Absol      Dark       NaN    465   65
# 393          359            AbsolMega Absol      Dark       NaN    565   65
# 396          362                     Glalie       Ice       NaN    480   80
# 397          362          GlalieMega Glalie       Ice       NaN    580   80
# 408          373                  Salamence    Dragon    Flying    600   95
# 409          373    SalamenceMega Salamence    Dragon    Flying    700   95
# 412          376                  Metagross     Steel   Psychic    600   80
# 413          376    MetagrossMega Metagross     Steel   Psychic    700   80
# 417          380                     Latias    Dragon   Psychic    600   80
# 418          380          LatiasMega Latias    Dragon   Psychic    700   80
# 419          381                     Latios    Dragon   Psychic    600   80
# 420          381          LatiosMega Latios    Dragon   Psychic    700   80
# 421          382                     Kyogre     Water       NaN    670  100
# 422          382        KyogrePrimal Kyogre     Water       NaN    770  100
# 423          383                    Groudon    Ground       NaN    670  100
# 424          383      GroudonPrimal Groudon    Ground      Fire    770  100
# 425          384                   Rayquaza    Dragon    Flying    680  105
# 426          384      RayquazaMega Rayquaza    Dragon    Flying    780  105
# 428          386         DeoxysNormal Forme   Psychic       NaN    600   50
# 429          386         DeoxysAttack Forme   Psychic       NaN    600   50
# 430          386        DeoxysDefense Forme   Psychic       NaN    600   50
# 431          386          DeoxysSpeed Forme   Psychic       NaN    600   50
# 458          413        WormadamPlant Cloak       Bug     Grass    424   60
# 459          413        WormadamSandy Cloak       Bug    Ground    424   60
# 460          413        WormadamTrash Cloak       Bug     Steel    424   60
# 475          428                    Lopunny    Normal       NaN    480   65
# 476          428        LopunnyMega Lopunny    Normal  Fighting    580   65
# 493          445                   Garchomp    Dragon    Ground    600  108
# 494          445      GarchompMega Garchomp    Dragon    Ground    700  108
# 497          448                    Lucario  Fighting     Steel    525   70
# 498          448        LucarioMega Lucario  Fighting     Steel    625   70
# 510          460                  Abomasnow     Grass       Ice    494   90
# 511          460    AbomasnowMega Abomasnow     Grass       Ice    594   90
# 526          475                    Gallade   Psychic  Fighting    518   68
# 527          475        GalladeMega Gallade   Psychic  Fighting    618   68
# 531          479                      Rotom  Electric     Ghost    440   50
# 532          479            RotomHeat Rotom  Electric      Fire    520   50
# 533          479            RotomWash Rotom  Electric     Water    520   50
# 534          479           RotomFrost Rotom  Electric       Ice    520   50
# 535          479             RotomFan Rotom  Electric    Flying    520   50
# 536          479             RotomMow Rotom  Electric     Grass    520   50
# 544          487      GiratinaAltered Forme     Ghost    Dragon    680  150
# 545          487       GiratinaOrigin Forme     Ghost    Dragon    680  150
# 550          492          ShayminLand Forme     Grass       NaN    600  100
# 551          492           ShayminSky Forme     Grass    Flying    600  100
# 590          531                     Audino    Normal       NaN    445  103
# 591          531          AudinoMega Audino    Normal     Fairy    545  103
# 615          555    DarmanitanStandard Mode      Fire       NaN    480  105
# 616          555         DarmanitanZen Mode      Fire   Psychic    540  105
# 702          641    TornadusIncarnate Forme    Flying       NaN    580   79
# 703          641      TornadusTherian Forme    Flying       NaN    580   79
# 704          642   ThundurusIncarnate Forme  Electric    Flying    580   79
# 705          642     ThundurusTherian Forme  Electric    Flying    580   79
# 708          645    LandorusIncarnate Forme    Ground    Flying    600   89
# 709          645      LandorusTherian Forme    Ground    Flying    600   89
# 710          646                     Kyurem    Dragon       Ice    660  125
# 711          646         KyuremBlack Kyurem    Dragon       Ice    700  125
# 712          646         KyuremWhite Kyurem    Dragon       Ice    700  125
# 713          647       KeldeoOrdinary Forme     Water  Fighting    580   91
# 714          647       KeldeoResolute Forme     Water  Fighting    580   91
# 715          648         MeloettaAria Forme    Normal   Psychic    600  100
# 716          648    MeloettaPirouette Forme    Normal  Fighting    600  100
# 746          678               MeowsticMale   Psychic       NaN    466   74
# 747          678             MeowsticFemale   Psychic       NaN    466   74
# 750          681       AegislashBlade Forme     Steel     Ghost    520   60
# 751          681      AegislashShield Forme     Steel     Ghost    520   60
# 780          710      PumpkabooAverage Size     Ghost     Grass    335   49
# 781          710        PumpkabooSmall Size     Ghost     Grass    335   44
# 782          710        PumpkabooLarge Size     Ghost     Grass    335   54
# 783          710        PumpkabooSuper Size     Ghost     Grass    335   59
# 784          711      GourgeistAverage Size     Ghost     Grass    494   65
# 785          711        GourgeistSmall Size     Ghost     Grass    494   55
# 786          711        GourgeistLarge Size     Ghost     Grass    494   75
# 787          711        GourgeistSuper Size     Ghost     Grass    494   85
# 795          719                    Diancie      Rock     Fairy    600   50
# 796          719        DiancieMega Diancie      Rock     Fairy    700   50
# 797          720        HoopaHoopa Confined   Psychic     Ghost    600   80
# 798          720         HoopaHoopa Unbound   Psychic      Dark    680   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        82       83      100      100     80           1      False
# 3       100      123      122      120     80           1      False
# 6        84       78      109       85    100           1      False
# 7       130      111      130       85    100           1      False
# 8       104       78      159      115    100           1      False
# 11       83      100       85      105     78           1      False
# 12      103      120      135      115     78           1      False
# 18       90       40       45       80     75           1      False
# 19      150       40       15       80    145           1      False
# 22       80       75       70       70    101           1      False
# 23       80       80      135       80    121           1      False
# 70       50       45      135       95    120           1      False
# 71       50       65      175       95    150           1      False
# 86       75      110      100       80     30           1      False
# 87       75      180      130       80     30           1      False
# 101      65       60      130       75    110           1      False
# 102      65       80      170       95    130           1      False
# 123      95       80       40       80     90           1      False
# 124     125      100       60      100    100           1      False
# 136     125      100       55       70     85           1      False
# 137     155      120       65       90    105           1      False
# 140     125       79       60      100     81           1      False
# 141     155      109       70      130     81           1      False
# 153     105       65       60       75    130           1      False
# 154     135       85       70       95    150           1      False
# 162     110       90      154       90    130           1       True
# 163     190      100      154      100    130           1       True
# 164     150       70      194      120    140           1       True
# 195      75       85      115       90     55           2      False
# 196      95      105      165      110     45           2      False
# 223      85      200       55       65     30           2      False
# 224     125      230       55       95     30           2      False
# 228     130      100       55       80     65           2      False
# 229     150      140       65      100     75           2      False
# 231     125       75       40       95     85           2      False
# 232     185      115       40      105     75           2      False
# 247      90       50      110       80     95           2      False
# 248      90       90      140       90    115           2      False
# 267     134      110       95      100     61           2      False
# 268     164      150       95      120     71           2      False
# 274      85       65      105       85    120           3      False
# 275     110       75      145       85    145           3      False
# 278     120       70      110       70     80           3      False
# 279     160       80      130       80    100           3      False
# 282     110       90       85       90     60           3      False
# 283     150      110       95      110     70           3      False
# 305      65       65      125      115     80           3      False
# 306      85       65      165      135    100           3      False
# 326      75       75       65       65     50           3      False
# 327      85      125       85      115     20           3      False
# 328      85       85       55       55     50           3      False
# 329     105      125       55       95     50           3      False
# 332     110      180       60       60     50           3      False
# 333     140      230       60       80     50           3      False
# 335      60       75       60       75     80           3      False
# 336     100       85       80       85    100           3      False
# 338      75       60      105       60    105           3      False
# 339      75       80      135       80    135           3      False
# 348     120       40       95       40     95           3      False
# 349     140       70      110       65    105           3      False
# 353     100       70      105       75     40           3      False
# 354     120      100      145      105     20           3      False
# 365      70       90       70      105     80           3      False
# 366     110      110      110      105     80           3      False
# 386     115       65       83       63     65           3      False
# 387     165       75       93       83     75           3      False
# 392     130       60       75       60     75           3      False
# 393     150       60      115       60    115           3      False
# 396      80       80       80       80     80           3      False
# 397     120       80      120       80    100           3      False
# 408     135       80      110       80    100           3      False
# 409     145      130      120       90    120           3      False
# 412     135      130       95       90     70           3      False
# 413     145      150      105      110    110           3      False
# 417      80       90      110      130    110           3       True
# 418     100      120      140      150    110           3       True
# 419      90       80      130      110    110           3       True
# 420     130      100      160      120    110           3       True
# 421     100       90      150      140     90           3       True
# 422     150       90      180      160     90           3       True
# 423     150      140      100       90     90           3       True
# 424     180      160      150       90     90           3       True
# 425     150       90      150       90     95           3       True
# 426     180      100      180      100    115           3       True
# 428     150       50      150       50    150           3       True
# 429     180       20      180       20    150           3       True
# 430      70      160       70      160     90           3       True
# 431      95       90       95       90    180           3       True
# 458      59       85       79      105     36           4      False
# 459      79      105       59       85     36           4      False
# 460      69       95       69       95     36           4      False
# 475      76       84       54       96    105           4      False
# 476     136       94       54       96    135           4      False
# 493     130       95       80       85    102           4      False
# 494     170      115      120       95     92           4      False
# 497     110       70      115       70     90           4      False
# 498     145       88      140       70    112           4      False
# 510      92       75       92       85     60           4      False
# 511     132      105      132      105     30           4      False
# 526     125       65       65      115     80           4      False
# 527     165       95       65      115    110           4      False
# 531      50       77       95       77     91           4      False
# 532      65      107      105      107     86           4      False
# 533      65      107      105      107     86           4      False
# 534      65      107      105      107     86           4      False
# 535      65      107      105      107     86           4      False
# 536      65      107      105      107     86           4      False
# 544     100      120      100      120     90           4       True
# 545     120      100      120      100     90           4       True
# 550     100      100      100      100    100           4       True
# 551     103       75      120       75    127           4       True
# 590      60       86       60       86     50           5      False
# 591      60      126       80      126     50           5      False
# 615     140       55       30       55     95           5      False
# 616      30      105      140      105     55           5      False
# 702     115       70      125       80    111           5       True
# 703     100       80      110       90    121           5       True
# 704     115       70      125       80    111           5       True
# 705     105       70      145       80    101           5       True
# 708     125       90      115       80    101           5       True
# 709     145       90      105       80     91           5       True
# 710     130       90      130       90     95           5       True
# 711     170      100      120       90     95           5       True
# 712     120       90      170      100     95           5       True
# 713      72       90      129       90    108           5      False
# 714      72       90      129       90    108           5      False
# 715      77       77      128      128     90           5      False
# 716     128       90       77       77    128           5      False
# 746      48       76       83       81    104           6      False
# 747      48       76       83       81    104           6      False
# 750     150       50      150       50     60           6      False
# 751      50      150       50      150     60           6      False
# 780      66       70       44       55     51           6      False
# 781      66       70       44       55     56           6      False
# 782      66       70       44       55     46           6      False
# 783      66       70       44       55     41           6      False
# 784      90      122       58       75     84           6      False
# 785      85      122       58       75     99           6      False
# 786      95      122       58       75     69           6      False
# 787     100      122       58       75     54           6      False
# 795     100      150      100      150     50           6       True
# 796     160      110      160      110    110           6       True
# 797     110       60      150      130     70           6       True
# 798     160       60      170      130     80           6       True

# %% [markdown]
# Based on the preview above, we can see, although `Pokedex_num` has duplicate entries, each its entries shows different Pokemon `Name`.
#
# This could mean, `different Pokemon Name share same Pokedex_num`. Is this considered duplicate entry? let's take a closer look inside.

# %%
# Sample of duplicate `Pokedex_num`
# 'Pokedex_num' == 479

raw_df[
    (raw_df['Pokedex_num'] == 479)
]

# Different Pokemon `Name` shares the same `Pokedex_num`
# Out:
#      Pokedex_num              Name    Type 1  Type 2  Total  HP  Attack  \
# 531          479             Rotom  Electric   Ghost    440  50      50
# 532          479   RotomHeat Rotom  Electric    Fire    520  50      65
# 533          479   RotomWash Rotom  Electric   Water    520  50      65
# 534          479  RotomFrost Rotom  Electric     Ice    520  50      65
# 535          479    RotomFan Rotom  Electric  Flying    520  50      65
# 536          479    RotomMow Rotom  Electric   Grass    520  50      65
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 531       77       95       77     91           4      False
# 532      107      105      107     86           4      False
# 533      107      105      107     86           4      False
# 534      107      105      107     86           4      False
# 535      107      105      107     86           4      False
# 536      107      105      107     86           4      False

# %%
# Sample of duplicate `Pokedex_num`
# 'Pokedex_num' == 710

raw_df[
    (raw_df['Pokedex_num'] == 710)
]

# Different Pokemon `Name` shares the same `Pokedex_num`
# Out:
#      Pokedex_num                   Name Type 1 Type 2  Total  HP  Attack  \
# 780          710  PumpkabooAverage Size  Ghost  Grass    335  49      66
# 781          710    PumpkabooSmall Size  Ghost  Grass    335  44      66
# 782          710    PumpkabooLarge Size  Ghost  Grass    335  54      66
# 783          710    PumpkabooSuper Size  Ghost  Grass    335  59      66
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 780       70       44       55     51           6      False
# 781       70       44       55     56           6      False
# 782       70       44       55     46           6      False
# 783       70       44       55     41           6      False

# %%
# Sample of duplicate `Pokedex_num`
# 'Pokedex_num' == 6

raw_df[
    (raw_df['Pokedex_num'] == 6)
]

# Different Pokemon `Name` shares the same `Pokedex_num`
# Out:
#    Pokedex_num                       Name Type 1  Type 2  Total  HP  Attack  \
# 6            6                  Charizard   Fire  Flying    534  78      84
# 7            6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8            6  CharizardMega Charizard Y   Fire  Flying    634  78     104
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6       78      109       85    100           1      False
# 7      111      130       85    100           1      False
# 8       78      159      115    100           1      False

# %% [markdown]
# We could see from the result above, actualy although the Pokemon `Name` is different, it is still refers to the same Pokemon. Hence, they share the same `Pokedex_num`.
#
# We could see that `same Pokemon`, `could have` different `size` or `alternate form` even `Total` stats.
#
# > This also explain why there is difference between total data entries (which is 800 entries) and total pokemon stated from above page (which is 721 Pokemon).
#
# I also conclude, duplication value of `Pokedex_num` cannot be considered as unexpected missing values.

# %%
# Name: Name of each pokemon

x = raw_df['Name'].value_counts()
pd.set_option('display.max_rows', None)

print(x)
print(x.dtype)
# Out:
# Bulbasaur                    1
# Uxie                         1
# GalladeMega Gallade          1
# Probopass                    1
# Dusknoir                     1
# Froslass                     1
# Rotom                        1
# RotomHeat Rotom              1
# RotomWash Rotom              1
# RotomFrost Rotom             1
# RotomFan Rotom               1
# RotomMow Rotom               1
# Mesprit                      1
# Ivysaur                      1
# Azelf                        1
# Dialga                       1
# Palkia                       1
# Heatran                      1
# Regigigas                    1
# GiratinaAltered Forme        1
# GiratinaOrigin Forme         1
# Cresselia                    1
# Phione                       1
# Manaphy                      1
# Gallade                      1
# Porygon-Z                    1
# Mamoswine                    1
# Gliscor                      1
# Drapion                      1
# Croagunk                     1
# Toxicroak                    1
# Carnivine                    1
# Finneon                      1
# Lumineon                     1
# Mantyke                      1
# Snover                       1
# Abomasnow                    1
# AbomasnowMega Abomasnow      1
# Weavile                      1
# Magnezone                    1
# Lickilicky                   1
# Rhyperior                    1
# Tangrowth                    1
# Electivire                   1
# Magmortar                    1
# Togekiss                     1
# Yanmega                      1
# Leafeon                      1
# Glaceon                      1
# Darkrai                      1
# ShayminLand Forme            1
# ShayminSky Forme             1
# Munna                        1
# Pidove                       1
# Tranquill                    1
# Unfezant                     1
# Blitzle                      1
# Zebstrika                    1
# Roggenrola                   1
# Boldore                      1
# Gigalith                     1
# Woobat                       1
# Swoobat                      1
# Drilbur                      1
# Excadrill                    1
# Audino                       1
# AudinoMega Audino            1
# Timburr                      1
# Gurdurr                      1
# Conkeldurr                   1
# Tympole                      1
# Palpitoad                    1
# Seismitoad                   1
# Throh                        1
# Musharna                     1
# Simipour                     1
# Arceus                       1
# Panpour                      1
# Victini                      1
# Snivy                        1
# Servine                      1
# Serperior                    1
# Tepig                        1
# Pignite                      1
# Emboar                       1
# Oshawott                     1
# Dewott                       1
# Samurott                     1
# Patrat                       1
# Watchog                      1
# Lillipup                     1
# Herdier                      1
# Stoutland                    1
# Purrloin                     1
# Liepard                      1
# Pansage                      1
# Simisage                     1
# Pansear                      1
# Simisear                     1
# Skorupi                      1
# Hippowdon                    1
# Hippopotas                   1
# Rayquaza                     1
# Jirachi                      1
# DeoxysNormal Forme           1
# DeoxysAttack Forme           1
# DeoxysDefense Forme          1
# DeoxysSpeed Forme            1
# Turtwig                      1
# Grotle                       1
# Torterra                     1
# Chimchar                     1
# Monferno                     1
# Infernape                    1
# Piplup                       1
# Prinplup                     1
# Empoleon                     1
# Starly                       1
# Staravia                     1
# Staraptor                    1
# Bidoof                       1
# Bibarel                      1
# Kricketot                    1
# Kricketune                   1
# RayquazaMega Rayquaza        1
# GroudonPrimal Groudon        1
# Skarmory                     1
# Houndour                     1
# Houndoom                     1
# Granbull                     1
# SteelixMega Steelix          1
# Kingdra                      1
# Steelix                      1
# Hoppip                       1
# Skiploom                     1
# Jumpluff                     1
# Aipom                        1
# Sunkern                      1
# Sunflora                     1
# Yanma                        1
# Wooper                       1
# Quagsire                     1
# Espeon                       1
# Umbreon                      1
# Murkrow                      1
# Slowking                     1
# Misdreavus                   1
# Unown                        1
# Wobbuffet                    1
# Girafarig                    1
# Pineco                       1
# Forretress                   1
# Dunsparce                    1
# Gligar                       1
# HoundoomMega Houndoom        1
# Phanpy                       1
# Shiftry                      1
# SceptileMega Sceptile        1
# Combusken                    1
# Blaziken                     1
# BlazikenMega Blaziken        1
# Mudkip                       1
# Marshtomp                    1
# Swampert                     1
# SwampertMega Swampert        1
# Poochyena                    1
# Mightyena                    1
# Zigzagoon                    1
# Linoone                      1
# Wurmple                      1
# Silcoon                      1
# Beautifly                    1
# Cascoon                      1
# Dustox                       1
# Lotad                        1
# Lombre                       1
# Ludicolo                     1
# Seedot                       1
# Nuzleaf                      1
# Torchic                      1
# Sceptile                     1
# Donphan                      1
# Grovyle                      1
# Porygon2                     1
# Stantler                     1
# Smeargle                     1
# Tyrogue                      1
# Hitmontop                    1
# Smoochum                     1
# Elekid                       1
# Magby                        1
# Miltank                      1
# Blissey                      1
# Raikou                       1
# Entei                        1
# Suicune                      1
# Larvitar                     1
# Pupitar                      1
# Tyranitar                    1
# TyranitarMega Tyranitar      1
# Lugia                        1
# Ho-oh                        1
# Celebi                       1
# Treecko                      1
# Volcanion                    1
# Name: Name, dtype: int64
# int64

# %% [markdown]
# From result above for Name column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Type 1: Each pokemon has a type, this determines weakness/resistance to attacks
x = raw_df['Type 1'].value_counts(ascending=True)

print(x)
print(x.dtype)
# Out:
# Flying        4
# Fairy        17
# Ice          24
# Steel        27
# Fighting     27
# Poison       28
# Dark         31
# Ground       32
# Ghost        32
# Dragon       32
# Electric     44
# Rock         44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: Type 1, dtype: int64
# int64

# %% [markdown]
# From result above for Type 1 column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Type 2: Some pokemon are dual type and have 2
x = raw_df['Type 2'].value_counts(ascending=True)

print(x)
print(x.dtype)
# Out:
# Bug          3
# Normal       4
# Electric     6
# Fire        12
# Ghost       14
# Water       14
# Rock        14
# Ice         14
# Dragon      18
# Dark        20
# Steel       22
# Fairy       23
# Grass       25
# Fighting    26
# Psychic     33
# Poison      34
# Ground      35
# Flying      97
# Name: Type 2, dtype: int64
# int64

# %% [markdown]
# From result above for Type 2 column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Total: sum of all stats that come after this, a general guide to how strong a pokemon is
x = raw_df['Total'].value_counts()

print(x)
print(x.dtype)
# Out:
# 600    37
# 405    26
# 580    23
# 500    23
# 300    19
# 490    18
# 525    16
# 495    15
# 330    15
# 480    15
# 305    13
# 680    13
# 485    12
# 520    12
# 510    10
# 460    10
# 310    10
# 530    10
# 420     9
# 700     9
# 455     9
# 410     9
# 535     9
# 335     9
# 325     9
# 540     9
# 28      1
# 51      1
# 114     1
# 165     1
# 109     1
# 92      1
# 250     1
# 56      1
# 88      1
# 255     1
# 101     1
# 190     1
# 42      1
# 36      1
# 99      1
# 37      1
# 116     1
# 31      1
# 1       1
# 135     1
# 104     1
# 10      1
# 144     1
# 170     1
# 111     1
# 160     1
# 81      1
# 140     1
# 97      1
# Name: HP, dtype: int64
# int64

# %% [markdown]
# From result above for HP column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Attack: the base modifier for normal attacks (eg. Scratch, Punch)
x = raw_df['Attack'].value_counts()

print(x)
print(x.dtype)
# Out:
# 100    40
# 65     39
# 50     37
# 80     37
# 85     33
# 60     33
# 75     32
# 70     31
# 90     30
# 55     30
# 45     27
# 95     26
# 120    21
# 40     21
# 30     20
# 110    18
# 105    17
# 125    14
# 130    14
# 35     13
# 150    11
# 115     9
# 48      9
# 20      8
# 92      7
# 72      7
# 66      7
# 52      7
# 25      7
# 82      6
# 63      6
# 135     6
# 140     6
# 53      5
# 73      5
# 64      5
# 84      5
# 160     5
# 78      4
# 83      4
# 76      4
# 77      4
# 145     4
# 62      4
# 69      4
# 58      4
# 38      3
# 165     3
# 68      3
# 59      3
# 49      3
# 180     3
# 47      3
# 123     3
# 10      3
# 98      3
# 104     3
# 89      3
# 103     3
# 117     3
# 56      3
# 81      3
# 109     2
# 61      2
# 86      2
# 124     2
# 112     2
# 94      2
# 93      2
# 170     2
# 87      2
# 131     2
# 155     2
# 51      2
# 41      2
# 134     2
# 57      2
# 5       2
# 67      2
# 128     1
# 107     1
# 129     1
# 36      1
# 22      1
# 74      1
# 147     1
# 102     1
# 44      1
# 108     1
# 54      1
# 121     1
# 27      1
# 97      1
# 23      1
# 15      1
# 136     1
# 43      1
# 42      1
# 29      1
# 91      1
# 79      1
# 71      1
# 164     1
# 88      1
# 24      1
# 185     1
# 46      1
# 190     1
# 106     1
# 132     1
# 33      1
# Name: Attack, dtype: int64
# int64

# %% [markdown]
# From result above for Attack column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Defense: the base damage resistance against normal attacks
x = raw_df['Defense'].value_counts()

print(x)
print(x.dtype)
# Out:
# 70     54
# 50     49
# 60     46
# 80     39
# 40     36
# 65     36
# 90     35
# 100    33
# 45     32
# 55     32
# 85     29
# 95     26
# 75     26
# 35     23
# 105    15
# 30     14
# 120    13
# 115    11
# 48     11
# 110    11
# 130    10
# 63      7
# 62      7
# 67      7
# 150     7
# 58      6
# 78      6
# 125     6
# 72      6
# 43      6
# 140     6
# 77      6
# 122     5
# 107     5
# 53      5
# 52      5
# 15      4
# 88      4
# 20      4
# 79      4
# 76      4
# 86      4
# 57      4
# 64      4
# 44      4
# 37      3
# 230     3
# 66      3
# 68      3
# 42      3
# 34      3
# 160     3
# 180     3
# 83      3
# 84      2
# 47      2
# 135     2
# 145     2
# 118     2
# 39      2
# 91      2
# 71      2
# 49      2
# 38      2
# 32      2
# 69      2
# 41      2
# 73      2
# 25      2
# 200     2
# 5       2
# 111     1
# 89      1
# 103     1
# 133     1
# 82      1
# 23      1
# 131     1
# 59      1
# 112     1
# 129     1
# 123     1
# 54      1
# 33      1
# 119     1
# 184     1
# 99      1
# 87      1
# 126     1
# 106     1
# 97      1
# 56      1
# 108     1
# 116     1
# 109     1
# 94      1
# 28      1
# 102     1
# 168     1
# 10      1
# 51      1
# 61      1
# 121     1
# Name: Defense, dtype: int64
# int64

# %% [markdown]
# From result above for Defense column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
x = raw_df['Sp. Atk'].value_counts()

print(x)
print(x.dtype)
# Out:
# 60     51
# 40     49
# 65     44
# 50     39
# 55     35
# 45     33
# 70     30
# 35     29
# 85     27
# 95     27
# 80     27
# 100    27
# 30     24
# 90     21
# 105    20
# 75     18
# 110    16
# 120    14
# 125    13
# 130    11
# 25     11
# 150     9
# 115     9
# 44      8
# 83      8
# 20      8
# 58      7
# 135     7
# 81      6
# 61      6
# 63      5
# 62      5
# 74      5
# 92      4
# 69      4
# 145     4
# 54      4
# 53      4
# 97      4
# 140     4
# 109     4
# 73      4
# 15      4
# 98      3
# 77      3
# 37      3
# 48      3
# 10      3
# 72      3
# 57      3
# 56      3
# 76      3
# 170     3
# 79      3
# 59      3
# 180     3
# 24      2
# 68      2
# 49      2
# 112     2
# 67      2
# 103     2
# 42      2
# 129     2
# 32      2
# 27      2
# 99      2
# 87      2
# 131     2
# 46      2
# 43      2
# 154     2
# 36      2
# 165     2
# 160     2
# 114     2
# 47      2
# 94      2
# 71      2
# 107     1
# 91      1
# 106     1
# 111     1
# 51      1
# 93      1
# 33      1
# 128     1
# 39      1
# 122     1
# 88      1
# 23      1
# 104     1
# 108     1
# 116     1
# 132     1
# 86      1
# 38      1
# 41      1
# 64      1
# 159     1
# 78      1
# 31      1
# 194     1
# 29      1
# 175     1
# Name: Sp. Atk, dtype: int64
# int64

# %% [markdown]
# From result above for Sp. Atk column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# SP Def: the base damage resistance against special attacks
x = raw_df['Sp. Def'].value_counts()

print(x)
print(x.dtype)
# Out:
# 80     52
# 50     50
# 55     47
# 65     44
# 60     43
# 70     40
# 75     40
# 90     36
# 45     35
# 40     30
# 85     30
# 95     29
# 100    28
# 30     20
# 35     18
# 105    17
# 110    15
# 120    13
# 25     11
# 63     10
# 115    10
# 48      9
# 130     9
# 150     7
# 56      7
# 107     6
# 20      6
# 86      5
# 42      5
# 82      4
# 52      4
# 41      4
# 79      4
# 71      4
# 135     4
# 61      4
# 87      3
# 81      3
# 37      3
# 77      3
# 44      3
# 98      3
# 72      3
# 66      3
# 43      3
# 69      3
# 83      3
# 96      3
# 62      3
# 54      3
# 154     3
# 39      2
# 89      2
# 59      2
# 125     2
# 67      2
# 53      2
# 49      2
# 116     2
# 57      2
# 140     2
# 160     2
# 76      2
# 58      2
# 46      2
# 126     1
# 92      1
# 94      1
# 36      1
# 99      1
# 129     1
# 128     1
# 38      1
# 32      1
# 123     1
# 73      1
# 106     1
# 108     1
# 78      1
# 102     1
# 138     1
# 88      1
# 34      1
# 51      1
# 101     1
# 200     1
# 33      1
# 23      1
# 230     1
# 31      1
# 64      1
# 113     1
# Name: Sp. Def, dtype: int64
# int64

# %% [markdown]
# From result above for Sp. Def column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Speed: determines which pokemon attacks first each round
x = raw_df['Speed'].value_counts()

print(x)
print(x.dtype)
# Out:
# 50     46
# 60     44
# 70     37
# 65     36
# 30     35
# 80     33
# 40     32
# 90     31
# 100    31
# 55     30
# 45     29
# 95     27
# 85     27
# 35     22
# 75     16
# 110    15
# 20     15
# 105    12
# 115    11
# 25     10
# 15      9
# 58      8
# 108     7
# 101     7
# 68      6
# 48      6
# 42      6
# 71      6
# 130     6
# 43      5
# 86      5
# 120     5
# 36      5
# 56      5
# 64      5
# 97      5
# 91      5
# 32      4
# 66      4
# 52      4
# 57      4
# 23      4
# 28      4
# 67      4
# 81      4
# 78      4
# 99      4
# 72      4
# 150     4
# 76      3
# 92      3
# 84      3
# 74      3
# 112     3
# 29      3
# 145     3
# 104     3
# 38      3
# 41      3
# 10      3
# 98      3
# 125     3
# 44      3
# 51      3
# 83      3
# 46      3
# 73      2
# 69      2
# 111     2
# 116     2
# 59      2
# 106     2
# 109     2
# 77      2
# 135     2
# 47      2
# 93      2
# 63      2
# 5       2
# 61      2
# 140     2
# 121     2
# 31      2
# 33      2
# 102     2
# 62      1
# 126     1
# 89      1
# 49      1
# 87      1
# 118     1
# 128     1
# 54      1
# 122     1
# 79      1
# 103     1
# 127     1
# 22      1
# 160     1
# 180     1
# 88      1
# 114     1
# 34      1
# 39      1
# 24      1
# 82      1
# 113     1
# 123     1
# Name: Speed, dtype: int64
# int64

# %% [markdown]
# From result above for Speed column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Generation : determines which generation (in pokemon video game) is the pokemon from
x = raw_df['Generation'].value_counts()

print(x)
print(x.dtype)
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64
# int64

# %% [markdown]
# From result above for Generation column has no Non-standard missing and and unexpected missing values.
#
# Entries in this column matches the column description

# %%
# Legendary : determines wether a pokemon is legendary pokemon or not
x = raw_df['Legendary'].value_counts()

print(x)
print(x.dtype)
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64
# int64

# %% [markdown]
# From result above for legendary column has no Non-standard missing values and unexpected missing values.
#
# Entries in this column matches the column description

# %% [markdown]
# After checking all unique value from each column, I can conclude all possible `Standard missing value,` `Non-standard missing value,` & `Unexpected missing value` is already identified.
#
# These missing value will be taken care of in the next process.

# %% [markdown]
# ### IV.3 Replacing the missing value
# In this process, I will replace all missing value to a value that matches the column description

# %% [markdown]
# Based from above result, We know that `Type 2` is the only column that has missing value.
#
# Because `Type 2` determines Pokemon 2nd type, all pokemon who doesn't dual type pokemon will only have one type.
#
# Therefore I will replace all missing value into word `None`. means respective pokemon is single type Pokemon.

# %%
# Replace all Nan value into `None` 
raw_df['Type 2'].fillna('None', inplace=True)

# Cleaned dataset
clean_df = raw_df

clean_df.sample(10)

# `clean_df` will be used for further process and analysis.
# Out:
#      Pokedex_num               Name    Type 1   Type 2  Total  HP  Attack  \
# 101           94             Gengar     Ghost   Poison    500  60      65
# 721          653           Fennekin      Fire     None    307  40      45
# 725          657          Frogadier     Water     None    405  54      63
# 738          670            Floette     Fairy     None    371  54      45
# 605          545          Scolipede       Bug   Poison    485  60     100
# 53            48            Venonat       Bug   Poison    305  60      55
# 562          503           Samurott     Water     None    528  95     100
# 531          479              Rotom  Electric    Ghost    440  50      50
# 191          177               Natu   Psychic   Flying    320  40      50
# 420          381  LatiosMega Latios    Dragon  Psychic    700  80     130
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 101       60      130       75    110           1      False
# 721       40       62       60     60           6      False
# 725       52       83       56     97           6      False
# 738       47       75       98     52           6      False
# 605       89       55       69    112           5      False
# 53        50       40       55     45           1      False
# 562       85      108       70     70           5      False
# 531       77       95       77     91           4      False
# 191       45       70       45     70           2      False
# 420      100      160      120    110           3       True

# %% [markdown]
# ## V. Data Exploration
# In this process, I will exploring the cleaned dataset to gain insight and use it to answer the objectives.

# %% [markdown]
# ### V.1 First Objective
# My first objective is to investigate `Meowtwo`.

# %% [markdown]
#  I will search the dataset and try to make brief description about `Mewtwo`

# %%
# Search the `Mewtwo` inside dataset

clean_df.loc[clean_df['Name'] == 'Mewtwo']
# Out:
#      Pokedex_num    Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 162          150  Mewtwo  Psychic   None    680  106     110       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 162      154       90    130           1       True

# %% [markdown]
# From result above, I can describe `Mewtwo` as:
# - 1st Generation Pokemon
# - Is Legendary Pokemon
# - Single Type Pokemon, and is Psychic
# - Has overall stat of 680

# %% [markdown]
# But wait, what if `Mewtwo` has other form? let's check it!

# %%
# Use `Pokedex_num` to identify any other form of `Mewtwo`

clean_df.loc[clean_df['Pokedex_num'] == 150]
# Out:
#      Pokedex_num                 Name   Type 1    Type 2  Total   HP  Attack  \
# 162          150               Mewtwo  Psychic      None    680  106     110
# 163          150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164          150  MewtwoMega Mewtwo Y  Psychic      None    780  106     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True

# %% [markdown]
# I knew it!, `Mewtwo` has other form. This will add new description about `Mewtwo`:
# - `Has two other form`, Mega Mewtwo X & Mega Mewtwo Y
# - Mega Mewtwo X is dual type Pokemon
# - Mewtwo other form is far `more stronger!`, `Total stat` reach `780.`

# %% [markdown]
# Now, let's compare three `Mewtwo` stat. I will use bar graph for more compelling comparisson.

# %% [markdown]
# Before start plotting the graph, I will need those `Mewtwo` stats.
#
# From above result, we know that entries about `Mewtwo` are located at index number 162, 163, & 164.

# %%
# Collecting three `Mewtwo` stats

# Mewtwo Status
mewstat = clean_df.iloc[162].to_dict()
stat = list(mewstat.keys())[5:11]
point = list(mewstat.values())[5:11]

# Mega Mewtwo X Status
mewstatX = clean_df.iloc[163].to_dict()
statX = list(mewstatX.keys())[5:11]
pointX = list(mewstatX.values())[5:11]

# Mega Mewtwo Y Status
mewstatY = clean_df.iloc[164].to_dict()
statY = list(mewstatY.keys())[5:11]
pointY = list(mewstatY.values())[5:11]

# Check the collection result
print(stat)
print(point)
# Out:
# ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
# [106, 110, 90, 154, 90, 130]

# %% [markdown]
# After collecting those stats, now I will plot it into the bar graph

# %%
# set bar width
barWidth = 0.25
fig = plt.figure(figsize=(10, 7))

# Horizontal  Data Positioning
stat = np.arange(len(point))
statX = [x + barWidth for x in stat]
statY = [x + barWidth for x in statX]


# Plotting
mewt = plt.bar(stat, point, label='Mewtwo', width=barWidth)
mewtX = plt.bar(statX, pointX, label='Mega Mewtwo X', width=barWidth)
mewtY = plt.bar(statY, pointY, label='Mega Mewtwo Y', width=barWidth)

# Labeling
plt.xlabel('Status', fontweight = 'bold', fontsize = '20')
plt.ylabel('Points', fontweight = 'bold', fontsize = '20')
plt.xticks([r + barWidth for r in range(len(stat))], 
            ['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'])
plt.legend()

# Function for text label for each bar
def labeling(x):

    "Attach a text label above each bar displaying its height"

    for bar in x:
        plt.annotate(bar.get_height(),xy=(bar.get_x() + 0.01, bar.get_height()+3), fontsize=10)
    return

labeling(mewt)
labeling(mewtX)
labeling(mewtY)

# Print the graph
plt.show()

# %% [markdown]
# From above result I can conclude:
# - `Mewtwo` HP stat are same across form and is 106 points
# - `Mewtwo` will have the highest attack and defense stats in `Mega Mewtwo X` form
# - `Mewtwo` will have the highest Sp. attack and Sp. defense stats in `Mega Mewtwo Y` form
# - Although speed point is not much differ from one and other, `Mega Mewtwo Y` has the highest speed
#
# I will then use the result from 1st objective as my information in answering the second objective

# %% [markdown]
# ### V.2 Second Objective
# My second objective is to make a recommendation of Pokemon team consist of 6 of Pokemon to battle and capture Mewtwo

# %% [markdown]
# Before jump into second objective, I choose to flatten all three `Mewtwo` stat.
#
# The reason behind my decision is because we don't know what form `Mewtwo` will take during the battle.
#
# Maybe it can change its form as it like. So I'll just take the average points for each stat.

# %%
# Flatten three `Mewtwo` stats

mewtwo_df = clean_df[
    (clean_df['Pokedex_num']==150)
][['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].mean()

# put its stat into new list
mewtwo_flatten_stat = mewtwo_df.values

# Round it into 2 point behind comma
mewtwo_flatten_stat = [round(i,2) for i in mewtwo_flatten_stat]

print(mewtwo_flatten_stat)
len(mewtwo_flatten_stat)
# Out:
# [106.0, 150.0, 86.67, 167.33, 103.33, 133.33]
# 6

# %% [markdown]
# Average `Mewtwo` stat graph

# %%
# set figure size
fig = plt.figure(figsize=(10, 7))

# Plotting
avg_mewstat = plt.bar(stat, mewtwo_flatten_stat, label = 'Mewtwo avg stats', color = 'Orange')

# Labeling
plt.xlabel('Status', fontweight = 'bold', fontsize = '10')
plt.ylabel('Points', fontweight = 'bold', fontsize = '10')
plt.xticks(np.arange(len(mewtwo_flatten_stat)),['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'])
plt.legend()

# Attach a text label above each bar displaying its height
for bar in avg_mewstat:
    plt.annotate(bar.get_height(),xy=(bar.get_x() + 0.25, bar.get_height()+3,), fontsize=10)

# Print the graph
plt.show()

# %% [markdown]
# So here we go, the average of three `mewtwo` stat is here:
# - HP : 106
# - Attack : 150
# - Def : 86.67
# - Sp. Atk : 167.33
# - Sp. Def : 103.33
# - Speed : 133.33

# %% [markdown]
# In order to make a strong Pokemon team to battle and capture `Mewtwo`, I will search the dataset a Pokemon with stats close to or higher than `Mewtwo`.
#
# I also will utilize `Pokemon Type Chart` to determine what Pokemon type are best against `Mewtwo`

# %% [markdown]
# ### Pokemon Type Chart
# <img src="https://img.pokemondb.net/images/typechart.png"
#     alt = "Pokemon Type Chart"
#     style = 10px>
#
# The full type chart here displays the strengths and weaknesses of each type.
#
# Look down the left hand side for the attacking type, then move across to see how effective it is against each Pokémon type.

# %% [markdown]
# From chart above, we can see Pokemon that could deal `super-effective` damage to `Mewtwo (Psychic)` are `Bug, Ghost, & Dark` Type Pokemon.
#
# Pokemon that could deal `super-effective` damage to `Mega Mewtwo X (Psychic & Fighting)` are `Flying, Psychic, & Fairy` Type Pokemon.

# %% [markdown]
# ### Creating the Team!
# So, my Pokemon team criteria will be any Pokemon with:
# - `Non Legendary Pokemon`, because its almost impossible to catch other Legendary Pokemon first :(
# - `Bug, Ghost, Dark, Flying, Psychic, or Fairy` Type Pokemon
# - Have stats close to or higher than average `Mewtwo` stats

# %% [markdown]
# First, let's filter the dataset.

# %%
# Set Pokemon Type Criteria
criteria = ['Bug', 'Ghost', 'Dark', 'Flying', 'Psychic', 'Fairy']

# Filter the Pokemon Type
Poke_team = clean_df.loc[
    (clean_df['Type 2'].isin(criteria)) |
    (clean_df['Type 1'].isin(criteria)) 
    #(clean_df['Legendary']==False) 
]

# Filter the Legendary status
Poke_team = Poke_team.loc[
    (Poke_team['Legendary']==False)
]

Poke_team.sort_values('Total', ascending=False, inplace=True)

# Let's see first 20 Pokemon
Poke_team.head(20)
# Out:
#      Pokedex_num                       Name   Type 1    Type 2  Total   HP  \
# 413          376    MetagrossMega Metagross    Steel   Psychic    700   80
# 268          248    TyranitarMega Tyranitar     Rock      Dark    700  100
# 409          373    SalamenceMega Salamence   Dragon    Flying    700   95
# 141          130      GyaradosMega Gyarados    Water      Dark    640   95
# 8              6  CharizardMega Charizard Y     Fire    Flying    634   78
# 306          282    GardevoirMega Gardevoir  Psychic     Fairy    618   68
# 527          475        GalladeMega Gallade  Psychic  Fighting    618   68
# 154          142  AerodactylMega Aerodactyl     Rock    Flying    615   80
# 412          376                  Metagross    Steel   Psychic    600   80
# 248          229      HoundoomMega Houndoom     Dark      Fire    600   75
# 267          248                  Tyranitar     Rock      Dark    600  100
# 271          251                     Celebi  Psychic     Grass    600  100
# 229          212          ScizorMega Scizor      Bug     Steel    600   70
# 102           94          GengarMega Gengar    Ghost    Poison    600   60
# 408          373                  Salamence   Dragon    Flying    600   95
# 137          127          PinsirMega Pinsir      Bug    Flying    600   65
# 546          488                  Cresselia  Psychic      None    600  120
# 165          151                        Mew  Psychic      None    600  100
# 161          149                  Dragonite   Dragon    Flying    600   91
# 696          635                  Hydreigon     Dark    Dragon    600   92
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 413     145      150      105      110    110           3      False
# 268     164      150       95      120     71           2      False
# 409     145      130      120       90    120           3      False
# 141     155      109       70      130     81           1      False
# 8       104       78      159      115    100           1      False
# 306      85       65      165      135    100           3      False
# 527     165       95       65      115    110           4      False
# 154     135       85       70       95    150           1      False
# 412     135      130       95       90     70           3      False
# 248      90       90      140       90    115           2      False
# 267     134      110       95      100     61           2      False
# 271     100      100      100      100    100           2      False
# 229     150      140       65      100     75           2      False
# 102      65       80      170       95    130           1      False
# 408     135       80      110       80    100           3      False
# 137     155      120       65       90    105           1      False
# 546      70      120       75      130     85           4      False
# 165     100      100      100      100    100           1      False
# 161     134       95      100      100     80           1      False
# 696     105       90      125       90     98           5      False

# %% [markdown]
# From result above, we could see that the closest  Pokemon that has overall stat closes to `Mewtwo` (700 points) are `Mega Metagross`, `Mega Tyranitar`, & `Mega Salamance`.They are all Pokemon with `Mega form`.
#
# Strongest Pokemon with `Base form` only reach 600 points in total stats.

# %% [markdown]
# Based on result above, I will recommend a team consist of:
# - `Mega Metagross` (Metagross) -- (Steel, Psychic, high in Atk & Def)
# - `Mega Tyranitar` (Tyranitar) -- (Rock, Dark, high in Atk & Def)
# - `Mega Salamence` (Salamence) -- (Dragon, Flying, high in Atk & Def)
# - `Mega Gyarados` (Gyarados) -- (Water, Dark, high in Atk & Sp. Def)
# - `Mega Gengar` (Gengar) -- (Ghost, Poison, high in Sp. Atk & Speed)
# - `Hydreigon` -- (Dark, Dragon, high in Sp. Atk & HP)
#
# Battle a Legendary Pokemon is sure is hard, we need Pokemon with `Mega form` to balance its power.
#
# Here is my team stats:

# %%
# Chosen Pokemon
team_stat = ['Metagross', 'Tyranitar', 'Salamence', 'Gyarados', 'Gengar', 'Hydreigon', 
'MetagrossMega Metagross', 'TyranitarMega Tyranitar', 'SalamenceMega Salamence', 'GyaradosMega Gyarados', 'GengarMega Gengar']

# Filter the dataframe to shows chosen Pokemon stat
# Short by their Pokedex_num then Total stats
Poke_team = Poke_team.loc[
        (Poke_team['Name'].isin(team_stat))
][['Pokedex_num','Name','Type 1','Type 2','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].sort_values(by=['Pokedex_num', 'Total'])

Poke_team
# Out:
#      Pokedex_num                     Name  Type 1   Type 2  Total   HP  \
# 101           94                   Gengar   Ghost   Poison    500   60
# 102           94        GengarMega Gengar   Ghost   Poison    600   60
# 140          130                 Gyarados   Water   Flying    540   95
# 141          130    GyaradosMega Gyarados   Water     Dark    640   95
# 267          248                Tyranitar    Rock     Dark    600  100
# 268          248  TyranitarMega Tyranitar    Rock     Dark    700  100
# 408          373                Salamence  Dragon   Flying    600   95
# 409          373  SalamenceMega Salamence  Dragon   Flying    700   95
# 412          376                Metagross   Steel  Psychic    600   80
# 413          376  MetagrossMega Metagross   Steel  Psychic    700   80
# 696          635                Hydreigon    Dark   Dragon    600   92
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed
# 101      65       60      130       75    110
# 102      65       80      170       95    130
# 140     125       79       60      100     81
# 141     155      109       70      130     81
# 267     134      110       95      100     61
# 268     164      150       95      120     71
# 408     135       80      110       80    100
# 409     145      130      120       90    120
# 412     135      130       95       90     70
# 413     145      150      105      110    110
# 696     105       90      125       90     98

# %% [markdown]
# Here is my team average stats:

# %%
# Team average stat
# Averaging their base stats and their mega form stats

criteria2 = [94, 130, 248, 373, 376, 635]

Poke_team[
    (Poke_team['Pokedex_num'].isin(criteria2))
].groupby(['Pokedex_num']).agg({'Total':'mean', 'HP':'mean', 'Attack':'mean', 'Defense':'mean', 
                                'Sp. Atk':'mean', 'Sp. Def':'mean', 'Speed':'mean'})
# Out:
#              Total     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Pokedex_num
# 94           550.0   60.0    65.0     70.0    150.0     85.0  120.0
# 130          590.0   95.0   140.0     94.0     65.0    115.0   81.0
# 248          650.0  100.0   149.0    130.0     95.0    110.0   66.0
# 373          650.0   95.0   140.0    105.0    115.0     85.0  110.0
# 376          650.0   80.0   140.0    140.0    100.0    100.0   90.0
# 635          600.0   92.0   105.0     90.0    125.0     90.0   98.0

# %% [markdown]
# And here is the strategies to battle and capture `Mewtwo`
#
# - If `Mewtwo` took its `Base form`. We can use `Tyranitar`, `Hydreigon`, or `Gengar`
# - If `Mewtwo` change to `Mega Mewtwo X`, which dual type and strong in Atk. & Def. We can counter it using `Mega Metagross`, `Mega Salamence`, or `Mega Gyarados`
# - If `Mewtwo` change to `Mega Mewtwo Y`, which strong in Sp. Atk & Sp. Def, We can counter it using `Mega Gyarados`, `Mega Gengar`, or `Hydreigon`

# %% [markdown]
# ## VI. Conclusion

# %% [markdown]
# ### VI.1 First Conclusion

# %% [markdown]
# ### Investigate `Mewtwo`:
# `Mewtwo` can be described as:
# - 1st Generation Legendary Pokemon
# - Psychic type Pokemon
# - Has high overall stats
# - Has two `Mega form`, Mega Mewtwo X & Mega Mewtwo Y
# - Mega Mewtwo X is dual type `Psychic` & `Fighting` Pokemon, strong in Atk and Def stats
# - Mega Mewtwo Y strong in Sp. Atk & Sp. Def
# - Has Weakness mainly to `Bug, Ghost, Dark, Flying, Psychic, or Fairy` Type Pokemon

# %% [markdown]
# ### VI.2 Second Conclusion

# %% [markdown]
# ### Recommendation of Pokemon team to battle and capture Mewtwo
#
# Based on my analysis, the best team would be consist of :
#
# - `Mega Metagross` (Metagross) -- (Steel, Psychic, high in Atk & Def)
# - `Mega Tyranitar` (Tyranitar) -- (Rock, Dark, high in Atk & Def)
# - `Mega Salamence` (Salamence) -- (Dragon, Flying, high in Atk & Def)
# - `Mega Gyarados` (Gyarados) -- (Water, Dark, high in Atk & Sp. Def)
# - `Mega Gengar` (Gengar) -- (Ghost, Poison, high in Sp. Atk & Speed)
# - `Hydreigon` -- (Dark, Dragon, high in Sp. Atk & HP)
#
# with the strategy of :
#
# - If `Mewtwo` took its `Base form`. We can use `Tyranitar`, `Hydreigon`, or `Gengar`
# - If `Mewtwo` change to `Mega Mewtwo X`, which dual type and strong in Atk. & Def. We can counter it using `Mega Metagross`, `Mega Salamence`, or `Mega Gyarados`
# - If `Mewtwo` change to `Mega Mewtwo Y`, which strong in Sp. Atk & Sp. Def, We can counter it using `Mega Gyarados`, `Mega Gengar`, or `Hydreigon`
